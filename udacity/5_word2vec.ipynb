# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
#!/usr/bin/env python3.6

# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2), (2, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'of', 'as', 'term', 'originated']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['a', 'originated', 'as', 'of', 'as', 'of', 'abuse', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("Variable/read:0", shape=(50000, 128), dtype=float32, device=/device:CPU:0)
# Tensor("embedding_lookup:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.167900
# Nearest to other: feelgood, musica, galloping, widebody, gravestone, highways, lager, martyn,
# Nearest to four: jornal, auteur, odour, megalithic, meccan, greenspan, perfectly, birthrate,
# Nearest to th: rationalize, criticises, tomorrow, menabrea, henotheism, labours, sata, rind,
# Nearest to between: hints, slow, revolt, specs, djamena, exhaustive, docklands, resented,
# Nearest to his: heaviest, granules, undermines, cfl, standardisation, millionaires, sachet, sufis,
# Nearest to for: abdal, justifying, canals, schultz, ist, ginette, rothbard, simplified,
# Nearest to a: restorer, signal, sark, complement, crime, schoenberg, heralds, rammstein,
# Nearest to five: sverdlovsk, mesopotamian, yoannis, screwball, javelin, sg, dramatically, hbc,
# Nearest to are: bardot, catal, dakuten, substitutions, follow, replacements, monophosphate, austroasiatic,
# Nearest to who: negotiator, barrow, folio, fullback, midland, doors, demonic, aedui,
# Nearest to be: pileser, goddess, shaping, nahum, flavors, claudel, stumbled, charles,
# Nearest to that: needless, guez, vied, anarchists, spooky, que, px, hallelujah,
# Nearest to by: decides, vodafone, crept, semaphore, ostpolitik, amity, slender, hohenzollern,
# Nearest to and: nuba, devotes, researched, dreadnought, curvature, wardens, renault, lac,
# Nearest to with: mali, hiragana, benefactor, doc, substitution, venona, worsen, backups,
# Nearest to only: doors, calvinism, iq, seeing, cyborgs, epiphenomenalism, eocene, au,
# Average loss at step 2000: 4.363161
# Average loss at step 4000: 3.871761
# Average loss at step 6000: 3.785764
# Average loss at step 8000: 3.685426
# Average loss at step 10000: 3.616179
# Nearest to other: musica, many, different, gigs, shakespearean, calvinist, sotho, some,
# Nearest to four: eight, three, six, five, seven, nine, two, zero,
# Nearest to th: eight, stuart, criticises, tomorrow, letterbox, gymnosperms, zero, disproving,
# Nearest to between: hints, removes, eazy, privy, djamena, into, failing, slow,
# Nearest to his: their, her, the, meditation, its, s, dignity, sighted,
# Nearest to for: in, with, lenovo, without, capitalistic, kuomintang, vaccine, biker,
# Nearest to a: the, this, recognised, bey, altitude, vedic, paradise, any,
# Nearest to five: six, eight, three, seven, four, nine, zero, two,
# Nearest to are: were, is, have, was, although, fabricate, include, catal,
# Nearest to who: he, which, they, huike, radically, dominos, and, caitlin,
# Nearest to be: have, is, gnu, was, pileser, hsieh, nationalistic, been,
# Nearest to that: which, it, anarchists, this, humourous, not, they, alphabetic,
# Nearest to by: was, as, from, peaches, retires, with, were, in,
# Nearest to and: or, presumptive, s, in, benito, cul, he, d,
# Nearest to with: in, for, endeavor, glue, nephropathy, sought, during, through,
# Nearest to only: asoka, tsui, exerts, calvinism, doors, allying, gil, wabash,
# Average loss at step 12000: 3.606134
# Average loss at step 14000: 3.571009
# Average loss at step 16000: 3.413892
# Average loss at step 18000: 3.457106
# Average loss at step 20000: 3.539921
# Nearest to other: many, different, these, consumer, some, such, sotho, baluchistan,
# Nearest to four: seven, eight, five, six, three, two, nine, zero,
# Nearest to th: eight, seven, stuart, disproving, gymnosperms, five, criticises, letterbox,
# Nearest to between: hints, with, in, from, privy, into, utero, soter,
# Nearest to his: their, her, its, the, meditation, resonances, manitou, sighted,
# Nearest to for: without, by, in, with, capitalistic, to, depatie, of,
# Nearest to a: this, the, any, recognised, glycolipids, peasants, spoiled, hunyadi,
# Nearest to five: seven, six, three, eight, four, zero, two, nine,
# Nearest to are: were, is, have, was, include, fabricate, gy, meals,
# Nearest to who: which, he, dominos, often, they, never, caitlin, also,
# Nearest to be: have, been, by, were, was, refer, is, uncanny,
# Nearest to that: which, anarchists, but, what, automotive, this, however, aladdin,
# Nearest to by: for, be, adm, centromere, in, with, was, been,
# Nearest to and: or, but, at, asanga, in, sour, kato, although,
# Nearest to with: nephropathy, in, or, for, between, through, during, glue,
# Nearest to only: exerts, findable, asoka, we, wabash, calvinism, counseling, idealism,
# Average loss at step 22000: 3.503744
# Average loss at step 24000: 3.494749
# Average loss at step 26000: 3.480652
# Average loss at step 28000: 3.486841
# Average loss at step 30000: 3.502551
# Nearest to other: different, consumer, many, these, sotho, some, regal, baluchistan,
# Nearest to four: five, six, eight, three, seven, two, nine, zero,
# Nearest to th: six, aqueduct, disproving, stuart, reversals, pacemaker, three, seven,
# Nearest to between: with, among, hints, privy, soter, from, within, over,
# Nearest to his: her, their, its, the, my, s, incestuous, meditation,
# Nearest to for: with, after, without, when, bolivia, of, lacks, dubbed,
# Nearest to a: the, any, casualty, spoiled, investment, shuttles, jeff, restorer,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to are: were, have, is, include, these, fabricate, be, while,
# Nearest to who: he, they, stalling, caitlin, never, always, she, which,
# Nearest to be: been, have, is, were, refer, was, are, cadbury,
# Nearest to that: which, what, however, but, aspirations, mama, this, anarchists,
# Nearest to by: was, were, as, in, from, trammell, when, with,
# Nearest to and: or, but, in, sour, steels, of, presumptive, however,
# Nearest to with: between, endeavor, for, in, under, entire, glue, mali,
# Nearest to only: wabash, no, here, exerts, occur, martyrs, findable, not,
# Average loss at step 32000: 3.501183
# Average loss at step 34000: 3.495285
# Average loss at step 36000: 3.451351
# Average loss at step 38000: 3.306759
# Average loss at step 40000: 3.431374
# Nearest to other: different, consumer, sotho, those, including, some, various, killers,
# Nearest to four: six, five, three, eight, seven, two, nine, one,
# Nearest to th: aqueduct, eight, rd, six, prelog, galba, disproving, nd,
# Nearest to between: among, within, over, across, into, with, privy, soter,
# Nearest to his: their, her, its, the, s, my, meditation, analytic,
# Nearest to for: in, if, with, lacks, after, dubbed, when, of,
# Nearest to a: the, any, or, another, baikonur, hitachi, savoie, turboprops,
# Nearest to five: three, six, four, seven, eight, two, zero, nine,
# Nearest to are: were, have, is, be, while, include, including, these,
# Nearest to who: which, often, he, electro, they, stalling, caitlin, also,
# Nearest to be: been, have, are, was, is, were, being, by,
# Nearest to that: which, however, what, this, aladdin, when, it, because,
# Nearest to by: with, when, be, peaches, zhu, adm, as, oswego,
# Nearest to and: or, while, in, but, alamanni, amino, sour, dacian,
# Nearest to with: by, scarlatti, including, in, nephropathy, endeavor, glue, for,
# Nearest to only: wabash, idealism, match, never, no, employs, always, asoka,
# Average loss at step 42000: 3.437911
# Average loss at step 44000: 3.451581
# Average loss at step 46000: 3.450751
# Average loss at step 48000: 3.358330
# Average loss at step 50000: 3.383759
# Nearest to other: different, various, many, political, killers, these, some, including,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to th: aqueduct, prelog, six, bc, five, galba, wane, skaters,
# Nearest to between: with, among, within, across, over, from, in, trammell,
# Nearest to his: her, their, its, my, the, your, meditation, him,
# Nearest to for: including, of, treatments, coulomb, asanga, chapelle, gravel, featuring,
# Nearest to a: the, another, any, recognised, casualty, rideau, cheated, exited,
# Nearest to five: four, six, seven, three, eight, two, zero, nine,
# Nearest to are: were, have, is, although, these, was, include, be,
# Nearest to who: he, which, often, she, also, electro, they, stalling,
# Nearest to be: been, have, was, being, become, were, is, cadbury,
# Nearest to that: which, however, mama, but, this, aladdin, who, where,
# Nearest to by: zhu, was, acclaim, newly, from, under, with, hypnosis,
# Nearest to and: or, but, however, including, of, while, in, s,
# Nearest to with: between, scarlatti, undoing, nephropathy, by, taxis, gave, including,
# Nearest to only: always, match, never, really, crews, employs, idealism, expressed,
# Average loss at step 52000: 3.437217
# Average loss at step 54000: 3.421465
# Average loss at step 56000: 3.438557
# Average loss at step 58000: 3.399369
# Average loss at step 60000: 3.392609
# Nearest to other: different, various, many, those, including, sotho, killers, fips,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Nearest to th: four, bc, six, aqueduct, five, eight, prelog, galba,
# Nearest to between: with, among, within, in, over, across, from, including,
# Nearest to his: her, their, its, my, analytic, meditation, antiprisms, the,
# Nearest to for: of, capitalistic, if, including, fittings, when, belongings, reuss,
# Nearest to a: another, any, the, exited, tilden, casualty, savoie, frozen,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to are: were, is, have, these, including, include, although, those,
# Nearest to who: he, still, which, often, they, electro, never, eventually,
# Nearest to be: been, become, being, cadbury, have, is, produce, was,
# Nearest to that: which, this, what, however, it, but, there, where,
# Nearest to by: centromere, through, with, adm, be, under, meso, zhu,
# Nearest to and: or, but, committees, than, including, sour, like, while,
# Nearest to with: between, by, in, including, cellulose, glue, cva, endeavor,
# Nearest to only: always, really, match, crews, occur, usually, employs, never,
# Average loss at step 62000: 3.244420
# Average loss at step 64000: 3.258645
# Average loss at step 66000: 3.406967
# Average loss at step 68000: 3.395427
# Average loss at step 70000: 3.361868
# Nearest to other: different, including, various, some, many, smaller, killers, diverse,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to th: bc, aqueduct, prelog, ad, galba, lyne, four, eight,
# Nearest to between: among, within, with, across, from, over, in, charset,
# Nearest to his: her, their, its, my, your, the, meditation, analytic,
# Nearest to for: in, reuss, against, using, dubbed, without, after, including,
# Nearest to a: the, another, hitachi, silvia, any, elliptical, turboprops, exited,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to are: were, is, have, include, including, although, these, contain,
# Nearest to who: he, which, still, they, she, stalling, often, electro,
# Nearest to be: been, being, become, is, have, were, cadbury, was,
# Nearest to that: which, however, what, this, but, where, aladdin, usually,
# Nearest to by: through, adm, be, using, under, from, centromere, awaited,
# Nearest to and: or, while, but, like, which, however, lovingly, of,
# Nearest to with: between, endeavor, scarlatti, fdi, glue, undoing, sine, through,
# Nearest to only: always, match, really, occur, never, not, usually, actually,
# Average loss at step 72000: 3.376814
# Average loss at step 74000: 3.346336
# Average loss at step 76000: 3.312542
# Average loss at step 78000: 3.350273
# Average loss at step 80000: 3.376874
# Nearest to other: various, including, regal, sotho, different, smaller, some, diverse,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to th: bc, five, aqueduct, four, seven, ad, rd, jacobian,
# Nearest to between: among, within, over, with, across, through, charset, in,
# Nearest to his: her, their, its, my, your, the, our, assembles,
# Nearest to for: against, without, dubbed, schultz, despite, including, after, capitalistic,
# Nearest to a: another, cheated, branched, silvia, exited, the, casualty, baikonur,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to are: were, have, include, is, although, these, those, including,
# Nearest to who: he, now, still, often, never, which, stalling, julia,
# Nearest to be: been, being, become, have, refer, cadbury, were, is,
# Nearest to that: which, however, this, tiberian, where, needless, tripartite, what,
# Nearest to by: through, meso, peaches, adm, from, lowry, strapped, when,
# Nearest to and: or, warped, while, but, typesetting, tectonics, dockyard, snipers,
# Nearest to with: between, scarlatti, wildly, publicist, endeavor, drummond, through, affirmative,
# Nearest to only: always, really, actually, idealism, winning, occur, crews, just,
# Average loss at step 82000: 3.409443
# Average loss at step 84000: 3.410207
# Average loss at step 86000: 3.392768
# Average loss at step 88000: 3.354879
# Average loss at step 90000: 3.366271
# Nearest to other: various, others, different, killers, individual, including, sotho, regal,
# Nearest to four: five, three, seven, six, eight, two, nine, zero,
# Nearest to th: bc, seven, aqueduct, eight, ad, prelog, nine, rd,
# Nearest to between: within, among, with, over, across, against, through, trammell,
# Nearest to his: her, their, its, my, your, the, our, s,
# Nearest to for: including, without, after, of, against, despite, dubbed, capitalistic,
# Nearest to a: another, the, cheated, any, every, baikonur, snapshots, prominently,
# Nearest to five: seven, four, six, eight, three, zero, nine, two,
# Nearest to are: were, is, include, have, these, although, contain, gainesville,
# Nearest to who: he, often, never, still, also, now, julia, stalling,
# Nearest to be: been, become, being, have, refer, was, is, promote,
# Nearest to that: which, however, tripartite, what, instead, tiberian, philologist, generally,
# Nearest to by: adm, through, under, bhaktivedanta, centromere, against, without, when,
# Nearest to and: or, but, including, warped, freenode, dermot, although, while,
# Nearest to with: between, publicist, in, endeavor, nephropathy, including, fdi, undoing,
# Nearest to only: always, actually, not, no, idealism, boles, speculator, usually,
# Average loss at step 92000: 3.399836
# Average loss at step 94000: 3.249810
# Average loss at step 96000: 3.360997
# Average loss at step 98000: 3.242778
# Average loss at step 100000: 3.361465
# Nearest to other: various, others, regal, smaller, including, chydenius, sotho, cpus,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to th: bc, aqueduct, rd, ad, one, disassembled, nd, prelog,
# Nearest to between: among, within, with, over, across, against, guanine, charset,
# Nearest to his: her, their, my, its, your, the, our, s,
# Nearest to for: after, when, without, including, if, despite, against, before,
# Nearest to a: another, any, the, elliptical, rideau, baikonur, enough, exited,
# Nearest to five: six, seven, four, eight, three, zero, two, nine,
# Nearest to are: were, have, is, gainesville, include, while, these, be,
# Nearest to who: he, never, which, still, also, julia, often, now,
# Nearest to be: been, have, being, become, is, refer, choose, easily,
# Nearest to that: which, however, what, who, aladdin, this, haaretz, forcible,
# Nearest to by: adm, without, appellation, under, when, through, be, hana,
# Nearest to and: or, but, while, like, although, however, when, of,
# Nearest to with: between, including, nephropathy, scarlatti, like, through, undoing, in,
# Nearest to only: always, no, actually, registration, not, never, crews, speculator,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# TODO: need to add num_skips
def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  
  for setIndex in range(skip_window, batch_size-skip_window):
    data_index = setIndex - skip_window
    batch_col = 0
    for index in range(data_index, data_index + skip_window):
      batch[data_index, batch_col] = data[index]
      batch_col = batch_col + 1
    labels[data_index] = data[data_index + skip_window]
#     print(data_index)
    for index in range(data_index + skip_window + 1, data_index + 2 * skip_window + 1):
      batch[data_index, batch_col] = data[index]
      batch_col = batch_col + 1
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for num_skips, skip_window in [(2, 1), (4, 2), (2, 4)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch[3]])
    print('    labels:', [reverse_dictionary[li] for li in labels[3]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['a', 'of']
#     labels: ['term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'term', 'abuse', 'first']
#     labels: ['of']
#
# with num_skips = 2 and skip_window = 4:
#     batch: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     labels: ['first']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_mean(embed, 1, keep_dims=False)
  print(embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("Mean:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# InvalidArgumentError: indices[126,0] = -492911888 is not in [0, 50000)
# 	 [[Node: embedding_lookup = Gather[Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@Variable"], validate_indices=true, _device="/job:localhost/replica:0/task:0/cpu:0"](Variable/read, _recv_Placeholder_0)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-24-9a8e4057aaed> in <module>()
#       9       batch_size, num_skips, skip_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12     average_loss += l
#      13     if step % 2000 == 0:
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# InvalidArgumentError: indices[126,0] = -492911888 is not in [0, 50000)
# 	 [[Node: embedding_lookup = Gather[Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@Variable"], validate_indices=true, _device="/job:localhost/replica:0/task:0/cpu:0"](Variable/read, _recv_Placeholder_0)]]
#
# Caused by op 'embedding_lookup', defined at:
#   File "/usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-23-4e5882944471>", line 32, in <module>
#     embed = tf.nn.embedding_lookup(embeddings, train_dataset)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/ops/embedding_ops.py", line 111, in embedding_lookup
#     validate_indices=validate_indices)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py", line 1359, in gather
#     validate_indices=validate_indices, name=name)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): indices[126,0] = -492911888 is not in [0, 50000)
# 	 [[Node: embedding_lookup = Gather[Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@Variable"], validate_indices=true, _device="/job:localhost/replica:0/task:0/cpu:0"](Variable/read, _recv_Placeholder_0)]]

# %%
print(matrix1)
# Out:
# Tensor("Const:0", shape=(2, 2), dtype=float32)

# %%
print(tf.reduce_mean(matrix1, 0))
# Out:
# Tensor("Mean:0", shape=(2,), dtype=float32)

# %%
a = tf.reduce_mean(matrix1, 0)

# %%
print(a)
# Out:
# Tensor("Mean_2:0", shape=(2,), dtype=float32)

# %%
sess = tf.Session()
result = sess.run(a)
print(result)
# Out:
# [ 1.5  1.5]
