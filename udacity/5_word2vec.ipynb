# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
#!/usr/bin/env python3.6

# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2), (2, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'originated', 'term', 'as', 'of']
#
# with num_skips = 2 and skip_window = 2:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['a', 'anarchism', 'as', 'term', 'of', 'abuse', 'first', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.838159
# Nearest to states: legalized, charles, underlined, cartesian, cryptology, gimmick, dismay, biblioth,
# Nearest to into: income, higham, bureaucracy, biz, dusty, inadvertent, satiric, chen,
# Nearest to are: devoid, executioner, survive, inferential, diocese, honorably, intonation, eml,
# Nearest to with: natives, weeks, atheromatous, cbc, doctorate, schengen, revenues, ibos,
# Nearest to between: homeopaths, teimanim, polonaise, moesia, seen, profiled, mitigated, hinders,
# Nearest to known: costumes, battlecruiser, approximants, stuttgart, theophilus, huckleberry, conciliation, mirabilis,
# Nearest to eight: biogeography, renga, combined, commemorating, full, castro, borealis, subjectivity,
# Nearest to of: gemini, macroevolution, takla, bosniak, ably, fuerza, tetra, lactantius,
# Nearest to he: ballets, khartoum, eyes, pasha, throttle, misuse, newark, motifs,
# Nearest to an: prosper, carradine, dvb, hunan, santa, critiques, thelma, abdera,
# Nearest to i: sophocles, jehoshaphat, given, prognosis, instability, shockwave, eos, simplify,
# Nearest to or: force, injector, crews, barter, voltaire, golgi, comprising, beazley,
# Nearest to american: pointe, slips, wings, whiz, cellos, walrus, coterminous, permits,
# Nearest to world: miniatures, celled, christiania, clinical, usurper, strains, stunted, defunct,
# Nearest to such: crusades, oromo, subsidized, gojira, initially, iconic, tanach, fertilization,
# Nearest to more: thoroughly, mattel, colleagues, dianic, mico, arabia, sup, diminish,
# Average loss at step 2000: 4.365319
# Average loss at step 4000: 3.868455
# Average loss at step 6000: 3.785523
# Average loss at step 8000: 3.686240
# Average loss at step 10000: 3.615363
# Nearest to states: investors, dismay, diogenes, charles, legalized, mechanical, symbolics, molarity,
# Nearest to into: satiric, beat, minions, to, insertion, higham, income, salah,
# Nearest to are: were, is, have, marne, was, include, does, shun,
# Nearest to with: between, reward, for, as, moderating, impulses, connecting, in,
# Nearest to between: moesia, kidd, with, homeopaths, tempering, too, teimanim, lya,
# Nearest to known: battlecruiser, well, costumes, senatorial, boutique, popolo, simon, used,
# Nearest to eight: nine, six, seven, five, three, four, zero, two,
# Nearest to of: in, for, southend, and, macroevolution, complexion, graviton, meisner,
# Nearest to he: it, she, they, who, iced, edd, also, johnson,
# Nearest to an: the, lengths, indus, dvb, straddles, disruptions, monsters, wicca,
# Nearest to i: given, eusebio, sophocles, jehoshaphat, shockwave, they, permitted, spinoff,
# Nearest to or: and, hashanah, bombs, clerks, hummingbird, deserves, handsome, xiaoping,
# Nearest to american: cellos, untersuchungen, d, pointe, montenegrins, standpoint, whiz, and,
# Nearest to world: myrrh, chair, manoeuvre, jh, revolts, christiania, quitting, ambassadors,
# Nearest to such: crusades, dilapidated, yesterday, corba, oromo, many, embryos, caecilius,
# Nearest to more: ethiopian, thoroughly, mattel, consummated, lancastrian, aubier, widely, any,
# Average loss at step 12000: 3.604966
# Average loss at step 14000: 3.570792
# Average loss at step 16000: 3.411664
# Average loss at step 18000: 3.459693
# Average loss at step 20000: 3.542987
# Nearest to states: diogenes, dismay, investors, symbolics, pools, surmised, legalized, mechanical,
# Nearest to into: from, satiric, against, minions, sectarianism, insertion, by, to,
# Nearest to are: were, is, have, be, but, was, betray, infamous,
# Nearest to with: between, in, reward, impulses, through, by, at, for,
# Nearest to between: with, from, kidd, moesia, including, tempering, prodigy, homeopaths,
# Nearest to known: used, battlecruiser, well, simon, costumes, senatorial, betrothal, far,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to of: macroevolution, for, opcode, bosniak, elmira, in, meisner, complexion,
# Nearest to he: it, she, they, who, there, breaded, then, this,
# Nearest to an: the, critiques, indus, straddles, lengths, dvb, monsters, garber,
# Nearest to i: we, they, ii, you, spinoff, bondi, density, mountbatten,
# Nearest to or: and, than, bombs, neutral, with, but, cam, quietly,
# Nearest to american: cellos, canadian, french, untersuchungen, yellow, faceted, silicate, italian,
# Nearest to world: jh, revolts, sugar, anabaptism, maliki, manoeuvre, myrrh, gesner,
# Nearest to such: many, well, dilapidated, these, yesterday, crusades, some, caecilius,
# Nearest to more: less, any, most, ethiopian, parole, freely, thoroughly, mattel,
# Average loss at step 22000: 3.502139
# Average loss at step 24000: 3.485383
# Average loss at step 26000: 3.485340
# Average loss at step 28000: 3.481012
# Average loss at step 30000: 3.499672
# Nearest to states: symbolics, diogenes, dismay, kingdom, liquids, nations, investors, countries,
# Nearest to into: from, insertion, under, against, satiric, sectarianism, knapp, minions,
# Nearest to are: were, is, have, include, those, but, other, these,
# Nearest to with: between, in, reward, when, through, moderating, crucible, impulses,
# Nearest to between: with, moesia, kidd, getz, from, including, before, throughout,
# Nearest to known: used, well, such, battlecruiser, regarded, seen, betrothal, far,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to of: in, complexion, seaport, southend, macroevolution, erotic, and, for,
# Nearest to he: she, it, they, who, there, breaded, pronunciation, but,
# Nearest to an: critiques, indus, straddles, meleon, disruptions, dvb, armament, mips,
# Nearest to i: ii, you, we, they, clones, iii, spinoff, phlogiston,
# Nearest to or: and, than, but, quietly, consciously, hashem, bereshit, speleological,
# Nearest to american: canadian, cellos, english, french, italian, replaces, british, standpoint,
# Nearest to world: jh, myrrh, civil, sink, crone, gulf, next, zoroastrian,
# Nearest to such: well, many, dilapidated, known, these, some, sobel, bins,
# Nearest to more: less, most, very, better, thoroughly, leung, widely, sacrifices,
# Average loss at step 32000: 3.501466
# Average loss at step 34000: 3.493239
# Average loss at step 36000: 3.451594
# Average loss at step 38000: 3.299670
# Average loss at step 40000: 3.426450
# Nearest to states: nations, kingdom, countries, symbolics, uphill, diogenes, unctad, bacon,
# Nearest to into: from, through, sectarianism, insertion, phosphor, against, satiric, beat,
# Nearest to are: were, have, include, is, but, these, be, lipstick,
# Nearest to with: between, kinsey, reward, ido, by, eprint, for, turismo,
# Nearest to between: with, from, teimanim, commences, millionaire, fringes, getz, oireachtas,
# Nearest to known: used, regarded, well, such, battlecruiser, possible, nuevo, seen,
# Nearest to eight: nine, seven, six, four, five, three, one, zero,
# Nearest to of: in, complexion, hymenoptera, for, southend, rebirth, richards, macroevolution,
# Nearest to he: she, it, they, who, there, breaded, then, i,
# Nearest to an: indus, dvb, critiques, disruptions, straddles, mips, monsters, isbns,
# Nearest to i: ii, you, we, they, iii, motala, he, iv,
# Nearest to or: and, than, a, dek, hedonism, trick, speleological, sane,
# Nearest to american: canadian, cellos, french, italian, english, british, german, standpoint,
# Nearest to world: gulf, jh, peloponnesian, crone, u, females, nile, understandable,
# Nearest to such: well, these, known, dilapidated, requiring, dynamo, sobel, biologist,
# Nearest to more: less, most, very, better, leung, sacrifices, processed, sinti,
# Average loss at step 42000: 3.441163
# Average loss at step 44000: 3.450364
# Average loss at step 46000: 3.448554
# Average loss at step 48000: 3.359330
# Average loss at step 50000: 3.380944
# Nearest to states: nations, kingdom, countries, symbolics, uphill, liquids, unctad, bacon,
# Nearest to into: through, from, under, over, towards, candela, knapp, within,
# Nearest to are: were, have, is, include, those, underscore, be, these,
# Nearest to with: between, moderating, expenses, by, pontifex, putonghua, additionally, enacts,
# Nearest to between: with, from, in, prodigy, getz, since, teimanim, throughout,
# Nearest to known: used, regarded, such, well, possible, seen, nuevo, ditch,
# Nearest to eight: seven, nine, six, four, five, three, zero, one,
# Nearest to of: in, macroevolution, davros, including, seaport, complexion, slavonic, sprite,
# Nearest to he: she, it, they, who, there, we, breaded, then,
# Nearest to an: monsters, critiques, dvb, indus, topping, situ, the, garber,
# Nearest to i: we, ii, you, iii, they, motala, he, spinoff,
# Nearest to or: and, than, gardening, quietly, but, including, sane, jfif,
# Nearest to american: cellos, british, canadian, pietro, english, french, italian, irish,
# Nearest to world: gulf, crone, jh, zoroastrian, peloponnesian, understandable, lenoir, patenting,
# Nearest to such: well, these, known, many, certain, dilapidated, everest, regarded,
# Nearest to more: less, most, leung, very, better, quite, sinti, hander,
# Average loss at step 52000: 3.430597
# Average loss at step 54000: 3.427491
# Average loss at step 56000: 3.442544
# Average loss at step 58000: 3.398200
# Average loss at step 60000: 3.389680
# Nearest to states: nations, kingdom, countries, liquids, dismay, us, merlot, nowy,
# Nearest to into: through, from, over, under, within, candela, dusty, insertion,
# Nearest to are: were, is, have, be, include, lipstick, underscore, although,
# Nearest to with: between, peshawar, including, in, by, when, turismo, additionally,
# Nearest to between: with, from, among, teimanim, including, in, getz, prodigy,
# Nearest to known: regarded, such, used, possible, well, seen, nuevo, described,
# Nearest to eight: nine, seven, six, five, four, three, zero, one,
# Nearest to of: in, for, same, killian, including, macroevolution, hymenoptera, like,
# Nearest to he: she, it, they, who, breaded, there, i, templars,
# Nearest to an: monsters, critiques, straddles, garber, breakbeat, topping, isbns, dvb,
# Nearest to i: we, ii, you, they, iii, spinoff, he, myocardial,
# Nearest to or: and, than, but, mangeshkar, libretto, including, trentino, prohibitive,
# Nearest to american: british, cellos, italian, african, pietro, irish, canadian, austrian,
# Nearest to world: crone, gulf, peloponnesian, unctad, patenting, jh, trivium, phrase,
# Nearest to such: known, well, dilapidated, certain, these, many, biologist, bins,
# Nearest to more: less, most, better, very, quite, stronger, sinti, leung,
# Average loss at step 62000: 3.234552
# Average loss at step 64000: 3.257255
# Average loss at step 66000: 3.405071
# Average loss at step 68000: 3.394411
# Average loss at step 70000: 3.360320
# Nearest to states: nations, kingdom, countries, symbolics, state, mandelbrot, unctad, nowy,
# Nearest to into: through, from, within, insertion, hamm, phosphor, over, across,
# Nearest to are: were, is, have, include, although, these, be, those,
# Nearest to with: between, turismo, additionally, peshawar, while, hostilities, moderating, ido,
# Nearest to between: with, from, teimanim, among, including, within, in, getz,
# Nearest to known: used, regarded, such, seen, possible, well, described, listed,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to of: including, in, and, papal, southend, include, canonical, psalter,
# Nearest to he: she, it, they, who, there, breaded, then, we,
# Nearest to an: straddles, critiques, breakbeat, monism, concur, restricts, garber, the,
# Nearest to i: we, ii, you, myocardial, spinoff, bakr, motala, iii,
# Nearest to or: and, than, but, normalization, libretto, aas, any, including,
# Nearest to american: british, italian, cellos, canadian, pietro, austrian, irish, european,
# Nearest to world: gulf, crone, peloponnesian, jh, phrase, u, cart, unincorporated,
# Nearest to such: these, well, known, certain, regarded, many, dilapidated, biologist,
# Nearest to more: less, most, very, better, quite, stronger, sinti, attackers,
# Average loss at step 72000: 3.376659
# Average loss at step 74000: 3.349140
# Average loss at step 76000: 3.314221
# Average loss at step 78000: 3.346458
# Average loss at step 80000: 3.374995
# Nearest to states: kingdom, nations, countries, state, unctad, symbolics, us, mandelbrot,
# Nearest to into: through, from, across, within, over, towards, insertion, off,
# Nearest to are: were, include, have, is, although, including, these, asdb,
# Nearest to with: between, turismo, blast, when, including, in, additionally, against,
# Nearest to between: with, from, in, among, teimanim, within, including, over,
# Nearest to known: regarded, used, seen, described, defined, possible, such, opposed,
# Nearest to eight: nine, six, seven, five, four, three, zero, one,
# Nearest to of: entire, in, including, macroevolution, throughout, yaw, leena, koala,
# Nearest to he: she, it, they, there, who, we, breaded, never,
# Nearest to an: watterson, critiques, monsters, straddles, situ, garber, ns, mantras,
# Nearest to i: ii, we, you, iii, spinoff, g, they, iv,
# Nearest to or: and, than, but, hashem, while, xk, cam, normalization,
# Nearest to american: british, canadian, irish, italian, international, austrian, european, impurity,
# Nearest to world: crone, peloponnesian, gulf, jh, usk, bnp, u, patenting,
# Nearest to such: well, these, certain, known, dilapidated, serious, sweetener, follows,
# Nearest to more: less, most, very, quite, better, hander, sinti, stronger,
# Average loss at step 82000: 3.409972
# Average loss at step 84000: 3.411863
# Average loss at step 86000: 3.387630
# Average loss at step 88000: 3.353472
# Average loss at step 90000: 3.365480
# Nearest to states: nations, kingdom, countries, state, us, symbolics, unctad, quantification,
# Nearest to into: through, from, across, pandemic, mutations, insertion, around, sectarianism,
# Nearest to are: were, include, is, have, these, asdb, although, those,
# Nearest to with: between, in, when, during, by, turismo, against, including,
# Nearest to between: with, within, from, teimanim, among, in, including, throughout,
# Nearest to known: used, regarded, described, such, seen, possible, opposed, called,
# Nearest to eight: seven, six, nine, five, four, three, two, zero,
# Nearest to of: including, for, in, during, davros, complexion, ultimate, torquato,
# Nearest to he: she, it, they, there, who, breaded, officially, we,
# Nearest to an: straddles, watterson, monsters, monism, critiques, skillful, situ, garber,
# Nearest to i: ii, we, you, g, spinoff, iii, bakr, f,
# Nearest to or: and, including, than, aas, jfif, monads, habitually, annuals,
# Nearest to american: british, canadian, italian, australian, austrian, french, irish, european,
# Nearest to world: peloponnesian, crone, phrase, gulf, jh, bnp, praises, understandable,
# Nearest to such: well, certain, known, these, including, sweetener, gbu, extremity,
# Nearest to more: less, most, very, better, quite, stronger, rather, longer,
# Average loss at step 92000: 3.399308
# Average loss at step 94000: 3.253656
# Average loss at step 96000: 3.361589
# Average loss at step 98000: 3.242880
# Average loss at step 100000: 3.360060
# Nearest to states: nations, kingdom, countries, us, symbolics, quantification, state, zalta,
# Nearest to into: through, from, within, across, in, under, around, towards,
# Nearest to are: were, is, have, include, although, be, while, being,
# Nearest to with: between, when, including, moderating, hostilities, while, during, fadh,
# Nearest to between: with, teimanim, among, within, from, fringes, cosmopolitan, madam,
# Nearest to known: regarded, such, used, possible, seen, defined, described, listed,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to of: including, and, in, hymenoptera, navigators, yoannis, moravian, same,
# Nearest to he: she, it, they, who, there, we, breaded, never,
# Nearest to an: another, orosius, breakbeat, topping, straddles, concur, garber, armament,
# Nearest to i: we, you, ii, they, spinoff, iii, camillo, motala,
# Nearest to or: and, than, normalization, while, carne, though, but, lev,
# Nearest to american: british, italian, canadian, french, irish, pietro, australian, international,
# Nearest to world: crone, peloponnesian, jh, gulf, phrase, nile, cart, country,
# Nearest to such: well, certain, known, these, many, classified, follows, including,
# Nearest to more: less, very, most, better, quite, stronger, highly, comforts,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# TODO: need to add num_skips
def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

  for i in range(batch_size):
    midpoint = data_index + skip_window
    batch[i] = np.array(data[data_index:midpoint] + data[midpoint+1:midpoint+skip_window+1])
    labels[i] = data[midpoint]
    data_index = (data_index + 1)
    
  return batch, labels    
#   for setIndex in range(0, batch_size):
#     data_index = data_index + 1
#     batch_col = 0
#     for index in range(setIndex, setIndex + skip_window):
#       assert(data[index] < vocabulary_size)
#       print(index)
#       assert(data[index] > 0)
#       batch[setIndex, batch_col] = data[index]
#       batch_col = batch_col + 1
#     labels[label_index] = data[setIndex + skip_window]
#     for index in range(setIndex + skip_window + 1, setIndex + 2 * skip_window + 1):
#       assert(data[index] < vocabulary_size)
#       print(index)
#       assert(data[index] > 0)
#       batch[setIndex, batch_col] = data[index]
#       batch_col = batch_col + 1
#   print(batch_col)
#   print(batch.shape)
#   print(labels.shape)
#   labels = np.reshape(labels, labels.shape)
#   print(labels)

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch[0]])
    print('    labels:', [reverse_dictionary[li] for li in labels[0]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as']
#     labels: ['originated']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term']
#     labels: ['as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_mean(embed, 1, keep_dims=False)
  print(embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("Mean:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.839774
# Nearest to can: myoglobin, lucan, headland, milky, chani, guarded, resort, belial,
# Nearest to d: rashi, hendrix, busting, moog, deliveries, gametes, orally, verdeans,
# Nearest to of: outermost, reg, hopelessly, starbucks, bringing, missionaries, ursula, sharpening,
# Nearest to and: rodrigo, catv, lor, tempos, aureus, sought, ito, jabal,
# Nearest to are: tashkent, aquilegia, motorcyclists, wandering, synonymous, tero, coal, suborder,
# Nearest to their: debug, roswell, tanenbaum, rde, tenacity, ifr, headlining, pickups,
# Nearest to also: shemini, desires, panics, diacritics, lobe, greta, sunnah, montpellier,
# Nearest to the: looney, professors, balaton, aq, ferrol, attenborough, proudhon, krak,
# Nearest to time: megalithic, refund, toho, progenitor, craggy, jungian, oratorio, amd,
# Nearest to used: waldorf, suffragan, nf, fingerprint, anarchist, hyginus, chaparral, peep,
# Nearest to his: imported, cellists, replace, sten, membrane, irreducibly, precursor, superstitions,
# Nearest to which: rez, tunisian, xxxv, paphos, humanistic, whoever, headquartered, hummers,
# Nearest to after: coexistence, trains, asic, appleby, fluent, lambeth, viii, conscience,
# Nearest to had: bordering, guericke, hurled, assault, netsplit, alexander, separator, mik,
# Nearest to at: yacht, categorization, prospectors, ascribe, hernandez, bender, flatulence, institutional,
# Nearest to an: desi, undulating, jaian, swedes, zone, irina, gottlob, circuits,
# Average loss at step 2000: 4.042010
# Average loss at step 4000: 3.512699
# Average loss at step 6000: 3.327717
# Average loss at step 8000: 3.217261
# Average loss at step 10000: 3.138844
# Nearest to can: would, may, will, could, myoglobin, might, must, astbury,
# Nearest to d: b, ischemic, moog, ito, gametes, mexican, guillain, buch,
# Nearest to of: compactly, in, outermost, recreations, for, hopelessly, coded, bangui,
# Nearest to and: or, rodrigo, advaita, dinaric, streamline, schelling, digby, who,
# Nearest to are: were, is, forward, extinctions, rescuing, tashkent, frantic, if,
# Nearest to their: its, his, the, her, debug, any, rivera, my,
# Nearest to also: often, sophie, signed, firefly, still, not, immunoglobulin, now,
# Nearest to the: their, its, a, this, his, some, any, her,
# Nearest to time: zariski, dynamism, chardin, motala, feudalism, fretless, model, nobleman,
# Nearest to used: waldorf, known, hazards, frankish, arabs, djvu, hor, supported,
# Nearest to his: their, her, its, the, sten, s, imported, hilbert,
# Nearest to which: that, however, who, hummers, indus, ditko, rez, these,
# Nearest to after: before, invisibly, trains, since, ghee, asic, from, grinder,
# Nearest to had: has, have, was, were, straddling, would, concave, previously,
# Nearest to at: in, pettigrew, mujahideen, spoils, meherabad, ascribe, bender, hernandez,
# Nearest to an: desi, the, ecclesiae, ballantine, acceptors, shiite, acquiring, headroom,
# Average loss at step 12000: 3.155250
# Average loss at step 14000: 3.141132
# Average loss at step 16000: 3.130290
# Average loss at step 18000: 3.112921
# Average loss at step 20000: 2.980375
# Nearest to can: may, will, could, would, might, must, should, cannot,
# Nearest to d: b, ischemic, champaign, brown, dualist, mexican, moog, affectation,
# Nearest to of: insertions, compactly, bangui, in, detoxification, including, recreations, sheba,
# Nearest to and: or, but, gulch, rodrigo, coulomb, which, beatified, wahhab,
# Nearest to are: were, is, rescuing, have, extinctions, geldof, tashkent, those,
# Nearest to their: its, his, her, the, any, my, our, these,
# Nearest to also: often, still, now, generally, sophie, firefly, slobodan, usually,
# Nearest to the: its, their, his, any, a, proudhon, each, her,
# Nearest to time: zariski, nobleman, convection, suzhou, death, chardin, feudalism, dynamism,
# Nearest to used: known, waldorf, seen, spook, djvu, arabs, believed, frankish,
# Nearest to his: their, her, its, the, dismissing, socialize, complaining, our,
# Nearest to which: that, this, who, these, however, hummers, repositories, seaports,
# Nearest to after: before, from, trains, ghee, sod, fluent, diamondbacks, for,
# Nearest to had: has, have, was, were, never, became, having, since,
# Nearest to at: in, pettigrew, mujahideen, ascribe, throughout, meherabad, during, someday,
# Nearest to an: desi, ballantine, swedes, supers, ecclesiae, acceptors, mil, acquiring,
# Average loss at step 22000: 3.058766
# Average loss at step 24000: 3.047713
# Average loss at step 26000: 2.964297
# Average loss at step 28000: 3.005030
# Average loss at step 30000: 2.987955
# Nearest to can: may, could, would, will, might, must, should, cannot,
# Nearest to d: b, ischemic, champaign, dualist, affectation, middlesex, elisabeth, buch,
# Nearest to of: insertions, recreations, compactly, outermost, bangui, sheba, turnaround, scarcely,
# Nearest to and: or, but, rodrigo, mcgill, asian, jasmine, beatified, devonian,
# Nearest to are: were, have, is, rescuing, extinctions, those, geldof, frantic,
# Nearest to their: its, his, her, my, the, our, these, any,
# Nearest to also: often, still, now, generally, usually, which, actually, typically,
# Nearest to the: their, its, proudhon, a, petomane, frg, jokes, extractive,
# Nearest to time: nobleman, year, feudalism, suzhou, convection, megalithic, hereford, zariski,
# Nearest to used: known, seen, believed, djvu, hor, supported, arabs, described,
# Nearest to his: their, her, its, my, your, our, extra, pd,
# Nearest to which: that, this, who, furnishings, also, what, however, hummers,
# Nearest to after: before, during, from, despite, when, selective, dawning, at,
# Nearest to had: has, have, was, were, having, concave, dialogues, gave,
# Nearest to at: during, throughout, in, pettigrew, ascribe, meherabad, after, campylobacter,
# Nearest to an: desi, swedes, supers, acceptors, irina, mil, royalties, ballantine,
# Average loss at step 32000: 2.976095
# Average loss at step 34000: 2.813547
# Average loss at step 36000: 2.937420
# Average loss at step 38000: 2.938221
# Average loss at step 40000: 2.920621
# Nearest to can: may, could, will, would, might, must, cannot, should,
# Nearest to d: b, affectation, champaign, dualist, ischemic, gozo, elisabeth, rousing,
# Nearest to of: insertions, including, recreations, throughout, in, accountancy, outermost, dm,
# Nearest to and: or, but, coulomb, merchandising, while, stronghold, including, ourselves,
# Nearest to are: were, have, is, rescuing, including, be, geldof, been,
# Nearest to their: its, his, her, the, my, our, these, beltaine,
# Nearest to also: often, still, now, actually, generally, usually, sometimes, typically,
# Nearest to the: their, its, a, frg, this, each, any, jokes,
# Nearest to time: nobleman, feudalism, year, megalithic, convection, elmer, hereford, benchmark,
# Nearest to used: known, seen, available, described, found, believed, hor, performed,
# Nearest to his: their, her, its, your, my, our, whose, pd,
# Nearest to which: that, this, these, furnishings, who, kabbalist, what, also,
# Nearest to after: before, during, despite, from, when, for, fluent, at,
# Nearest to had: have, has, was, were, having, dialogues, gave, began,
# Nearest to at: in, throughout, during, pettigrew, ascribe, around, mujahideen, after,
# Nearest to an: desi, acceptors, ballantine, supers, peuple, hostility, swedes, nisan,
# Average loss at step 42000: 2.918520
# Average loss at step 44000: 2.958327
# Average loss at step 46000: 2.911158
# Average loss at step 48000: 2.914021
# Average loss at step 50000: 2.836092
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to d: b, affectation, falla, gozo, es, rousing, webster, ischemic,
# Nearest to of: insertions, recreations, including, turnaround, sheba, outermost, compactly, in,
# Nearest to and: or, but, nimzowitsch, untouchables, cassell, including, aureus, donuts,
# Nearest to are: were, have, is, rescuing, remain, including, those, geldof,
# Nearest to their: its, his, her, our, my, your, the, these,
# Nearest to also: often, still, actually, now, generally, usually, sometimes, typically,
# Nearest to the: its, their, his, this, a, hormonal, every, petomane,
# Nearest to time: feudalism, year, nobleman, place, electroshock, benchmark, elmer, improvising,
# Nearest to used: known, available, seen, required, believed, referred, described, responsible,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to which: that, this, what, kabbalist, also, these, bilbao, who,
# Nearest to after: before, during, despite, when, without, while, sod, for,
# Nearest to had: has, have, was, were, having, began, ever, never,
# Nearest to at: in, during, pettigrew, throughout, mujahideen, blackmail, ascribe, after,
# Nearest to an: desi, supers, peuple, acceptors, hostility, swain, another, ballantine,
# Average loss at step 52000: 2.838774
# Average loss at step 54000: 2.867635
# Average loss at step 56000: 2.879203
# Average loss at step 58000: 2.735484
# Average loss at step 60000: 2.819950
# Nearest to can: could, may, will, would, must, might, cannot, should,
# Nearest to d: b, falla, affectation, c, gozo, ischemic, es, webster,
# Nearest to of: insertions, recreations, including, agape, heliogabalus, compactly, runequest, estonian,
# Nearest to and: or, but, while, although, meninges, pox, nimzowitsch, however,
# Nearest to are: were, have, is, remain, those, including, rescuing, be,
# Nearest to their: its, his, her, our, your, my, the, envoy,
# Nearest to also: often, still, now, actually, generally, usually, typically, sometimes,
# Nearest to the: its, frg, their, petomane, this, our, a, necked,
# Nearest to time: year, feudalism, nobleman, thing, improvement, improvising, elmer, episode,
# Nearest to used: known, seen, available, believed, required, found, performed, described,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to which: that, this, what, roderick, these, furnishings, also, who,
# Nearest to after: before, during, when, despite, without, while, at, from,
# Nearest to had: has, have, was, were, having, began, ever, never,
# Nearest to at: during, throughout, in, pettigrew, near, after, blackmail, eurythmics,
# Nearest to an: desi, peuple, circuits, ballantine, acceptors, swedes, shiite, supers,
# Average loss at step 62000: 2.847740
# Average loss at step 64000: 2.830028
# Average loss at step 66000: 2.716387
# Average loss at step 68000: 2.741856
# Average loss at step 70000: 2.774496
# Nearest to can: could, may, will, must, would, might, cannot, should,
# Nearest to d: b, ischemic, affectation, falla, bankhead, toppled, mexican, es,
# Nearest to of: insertions, recreations, in, including, bangui, sheba, outermost, heliogabalus,
# Nearest to and: or, but, digby, including, rebekah, toss, estranged, boiler,
# Nearest to are: were, have, is, include, be, those, rescuing, including,
# Nearest to their: its, his, her, our, your, the, my, envoy,
# Nearest to also: now, often, actually, still, generally, usually, always, never,
# Nearest to the: their, its, his, any, our, this, frg, supportive,
# Nearest to time: year, feudalism, improvising, thing, electroshock, nobleman, megalithic, hereford,
# Nearest to used: seen, available, required, known, believed, needed, found, referred,
# Nearest to his: her, their, my, your, its, our, the, whose,
# Nearest to which: that, this, also, what, who, roderick, bilbao, but,
# Nearest to after: before, during, despite, when, while, without, following, from,
# Nearest to had: has, have, was, having, were, began, never, ever,
# Nearest to at: in, during, throughout, near, pettigrew, mujahideen, rk, after,
# Nearest to an: peuple, desi, another, ballantine, supers, circuits, acceptors, mil,
# Average loss at step 72000: 2.756611
# Average loss at step 74000: 2.785727
# Average loss at step 76000: 2.666253
# Average loss at step 78000: 2.797072
# Average loss at step 80000: 2.814563
# Nearest to can: could, may, will, must, would, might, cannot, should,
# Nearest to d: b, falla, ischemic, es, toppled, affectation, middlesex, webster,
# Nearest to of: insertions, recreations, yersinia, greats, turnaround, honourable, waka, dcsd,
# Nearest to and: or, but, although, digby, however, coulomb, including, hornblower,
# Nearest to are: were, is, have, rescuing, include, those, remain, geldof,
# Nearest to their: its, his, her, our, your, my, the, these,
# Nearest to also: now, often, actually, still, generally, never, usually, typically,
# Nearest to the: a, their, any, its, his, our, this, your,
# Nearest to time: year, feudalism, improvising, improvement, kind, paleozoic, demeter, thing,
# Nearest to used: required, known, available, seen, referred, described, believed, responsible,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to which: that, this, what, roderick, these, bilbao, kabbalist, repositories,
# Nearest to after: before, during, when, despite, while, without, afterwards, possesses,
# Nearest to had: has, have, having, was, were, cruciform, rationalistic, ever,
# Nearest to at: near, during, in, throughout, eurythmics, flamboyant, pettigrew, meherabad,
# Nearest to an: desi, hostility, peuple, supers, ballantine, preprint, another, acceptors,
# Average loss at step 82000: 2.764601
# Average loss at step 84000: 2.679550
# Average loss at step 86000: 2.757904
# Average loss at step 88000: 2.733901
# Average loss at step 90000: 2.749423
# Nearest to can: could, may, would, will, must, might, cannot, should,
# Nearest to d: b, falla, affectation, es, ischemic, webster, gozo, middlesex,
# Nearest to of: insertions, recreations, turnaround, agape, waka, wuxia, honourable, dm,
# Nearest to and: or, but, coulomb, although, while, merchandising, nimzowitsch, including,
# Nearest to are: were, have, is, include, rescuing, those, remain, recommends,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to also: now, often, actually, still, never, generally, always, typically,
# Nearest to the: its, their, his, a, frg, our, any, plummeted,
# Nearest to time: year, feudalism, thing, episode, improvement, kind, improvising, electroshock,
# Nearest to used: required, seen, known, available, described, referred, responsible, sold,
# Nearest to his: her, their, my, your, its, our, whose, ump,
# Nearest to which: that, this, what, also, who, roderick, furnishings, bilbao,
# Nearest to after: before, during, when, despite, without, while, for, afterwards,
# Nearest to had: has, have, having, was, were, cruciform, took, rationalistic,
# Nearest to at: during, near, in, throughout, randomness, pettigrew, around, mujahideen,
# Nearest to an: ballantine, another, desi, supers, acceptors, peuple, hostility, aslan,
# Average loss at step 92000: 2.744424
# Average loss at step 94000: 2.668888
# Average loss at step 96000: 2.743098
# Average loss at step 98000: 2.702289
# Average loss at step 100000: 2.461593
# Nearest to can: could, may, will, must, would, cannot, might, should,
# Nearest to d: b, ischemic, falla, toppled, es, affectation, mexican, bottleneck,
# Nearest to of: insertions, despite, recreations, agape, outermost, alliaceae, bac, in,
# Nearest to and: or, rodrigo, but, including, american, digby, estranged, cassell,
# Nearest to are: were, have, include, is, remain, be, geldof, recommends,
# Nearest to their: its, his, her, our, your, my, the, envoy,
# Nearest to also: actually, now, never, often, still, generally, always, typically,
# Nearest to the: his, its, their, a, necked, nand, your, our,
# Nearest to time: thing, episode, feudalism, year, improvement, improvising, electroshock, kind,
# Nearest to used: required, known, seen, referred, available, sold, needed, responsible,
# Nearest to his: her, their, my, your, its, our, the, whose,
# Nearest to which: that, this, what, who, also, roderick, bilbao, these,
# Nearest to after: before, during, when, despite, without, while, afterwards, at,
# Nearest to had: has, have, was, having, were, cruciform, rationalistic, ever,
# Nearest to at: in, during, near, throughout, pettigrew, randomness, after, around,
# Nearest to an: ballantine, swain, desi, shirow, supers, acceptors, peuple, preprint,
